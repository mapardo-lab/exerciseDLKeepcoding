# %%
from utilsTrain import TrainModels

models_trained = TrainModels()

models_trained.summary('f1_score')
# Out:
#                       model_name           date_train        data_file  \
# 0    MDL_fcnn_pca_embeddings1_T0  2025-10-23 12:02:44  poi_dataset.csv
# 1  MDL_fcnn_shallow_metadata1_T1  2025-10-23 12:05:27  poi_dataset.csv
#
#    f1_score
# 0  0.000000
# 1  0.831461

# %%
import numpy as np
from utilsTrain import TrainModels

models_trained = TrainModels()

model_name = "MDL_fcnn_shallow_metadata1_T1"
models_trained.info_model(model_name)
# Out:
# Model name: MDL_fcnn_shallow_metadata1_T1
# Date training: 2025-10-23 12:05:27
# sensitivity: 1.0
# precision: 0.71
# f1_score: 0.83
# macro_precision: 0.71
# Confusion matrix: [[106, 60], [0, 148]]

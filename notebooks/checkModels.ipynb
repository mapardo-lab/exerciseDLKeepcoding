# %%
import os
import sys

os.chdir('..')
sys.path.append('src')

# %%
from utilsModel import TrainModels

models_trained = TrainModels()

models_trained.summary('f1_score')
# Out:
#                             model_name           date_train  \
# 0  MDL_mmodal3_pre_img1_meta1_emb1_T14  2025-11-01 21:34:41
# 1        MML_randomforest_metadata1_T3  2025-11-01 21:36:00
#
#               data_file  f1_score
# 0  data/poi_dataset.csv  0.860927
# 1  data/poi_dataset.csv  0.829132

# %%
from utilsModel import TrainModels

models_trained = TrainModels()

models_trained.remove_model('MDL_fcnn_shallow_metadata1_T8')
# Out:
# Model MDL_fcnn_shallow_metadata1_T8 removed

# %%
import numpy as np
from utilsModel import TrainModels

models_trained = TrainModels()

model_name = "MDL_mmodal3_pre_img1_meta1_emb1_T14"
models_trained.info_model(model_name)
# Out:
# Model name: MDL_mmodal3_pre_img1_meta1_emb1_T14
# Date training: 2025-11-01 21:34:41
# f1_score: 0.86
# sensitivity: 0.88
# precision: 0.84
# macro_precision: 0.84
# Confusion matrix: [[142, 24], [18, 130]]

# %%
import numpy as np
from utilsModel import TrainModels

models_trained = TrainModels()

model_name = "MML_randomforest_metadata1_T3"
models_trained.info_model(model_name)
# Out:
# Model name: MML_randomforest_metadata1_T3
# Date training: 2025-11-01 21:36:00
# f1_score: 0.83
# sensitivity: 1.0
# precision: 0.71
# macro_precision: 0.71
# Confusion matrix: [[105, 61], [0, 148]]
